# %%
import os
import json
from collections import defaultdict, Counter

root_path = "/root/autodl-tmp/data/radgraph/dygie++"

# %%
import shutil

output_dir = "./radgraph"
if os.path.exists(output_dir):
    shutil.rmtree(output_dir)

os.makedirs(output_dir)

# %%
cross_sent_relations = {
    "train": [],
    "dev": [],
    "test": [],
    "test1": [],
}

for out_file_name in ["train", "dev", "test", "test1"]:
    if out_file_name == "test1":
        in_file_name = "test"
    else:
        in_file_name = out_file_name

    input_file_path = os.path.join(root_path, f"{in_file_name}.json")
    with open(input_file_path, "r") as f:
        docs_dict = json.loads(f.readline())

    for doc_key, doc in docs_dict.items():
        output_dict = {
            "doc_key": doc_key,
            "sentences": [],
            "ner": [],
            "relations": [],
        }
        sent_idx = 0
        tokidx2sentidx = []
        tokens = doc["text"].split(" ")
        sent = []
        for token_id, token in enumerate(tokens):
            tokidx2sentidx.append(sent_idx)
            sent.append(token)
            if token == "." or token_id == len(tokens) - 1:
                output_dict["sentences"].append(sent)
                output_dict["ner"].append([])
                output_dict["relations"].append([])
                sent_idx += 1
                sent = []
        assert len(tokens) == len([i for sent in output_dict["sentences"] for i in sent])

        if out_file_name == "test":
            doc_entities = doc["labeler_1"]["entities"]
        elif out_file_name == "test1":
            doc_entities = doc["labeler_2"]["entities"]
        else:
            doc_entities = doc["entities"]

        for ent_idx, entity in doc_entities.items():
            subj_start = entity["start_ix"]
            subj_end = entity["end_ix"]
            subj_sent_idx = tokidx2sentidx[subj_start]
            output_dict["ner"][subj_sent_idx].append([subj_start, subj_end, entity["label"]])
            for rel in entity["relations"]:
                rel_label = rel[0]
                rel_obj_idx = rel[1]
                obj_start = doc_entities[rel_obj_idx]["start_ix"]
                obj_end = doc_entities[rel_obj_idx]["end_ix"]
                obj_sent_idx = tokidx2sentidx[obj_start]
                cross_sent_relations[out_file_name].append(abs(subj_sent_idx - obj_sent_idx))
                output_dict["relations"][subj_sent_idx].append([subj_start, subj_end, obj_start, obj_end, rel_label])
                if abs(subj_sent_idx - obj_sent_idx) > 0:
                    print(doc_key, entity)

        output_path = os.path.join(output_dir, f"{out_file_name}.json")
        with open(output_path, "a", encoding="utf-8") as f:
            f.write(json.dumps(output_dict))
            f.write("\n")
            
        if "txt" in doc_key and "test" in out_file_name:
            output_path = os.path.join(output_dir, f"{out_file_name}_mimic.json")
            with open(output_path, "a", encoding="utf-8") as f:
                f.write(json.dumps(output_dict))
                f.write("\n")
        if "txt" not in doc_key and "test" in out_file_name:
            output_path = os.path.join(output_dir, f"{out_file_name}_chexpert.json")
            with open(output_path, "a", encoding="utf-8") as f:
                f.write(json.dumps(output_dict))
                f.write("\n")
# Out:
# p18/p18003081/s51239857.txt {'tokens': 'This', 'label': 'OBS-DP', 'start_ix': 29, 'end_ix': 29, 'relations': [['modify', '1'], ['suggestive_of', '9']]}
# p18/p18003081/s51438902.txt {'tokens': 'They', 'label': 'OBS-DP', 'start_ix': 84, 'end_ix': 84, 'relations': [['modify', '4']]}
# p18/p18003081/s52648242.txt {'tokens': 'obscuring', 'label': 'OBS-DP', 'start_ix': 72, 'end_ix': 72, 'relations': [['located_at', '18'], ['suggestive_of', '19']]}
# p18/p18003081/s52648242.txt {'tokens': 'cannot be assessed', 'label': 'OBS-DP', 'start_ix': 77, 'end_ix': 79, 'relations': [['located_at', '18']]}
# p10/p10005749/s53170451.txt {'tokens': 'cardiomegaly', 'label': 'OBS-DP', 'start_ix': 8, 'end_ix': 8, 'relations': [['suggestive_of', '12']]}
# p10/p10005749/s53170451.txt {'tokens': 'effusions', 'label': 'OBS-DP', 'start_ix': 13, 'end_ix': 13, 'relations': [['located_at', '5'], ['suggestive_of', '12']]}
# p15/p15165563/s57008959.txt {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 33, 'end_ix': 33, 'relations': [['located_at', '7'], ['suggestive_of', '12'], ['suggestive_of', '15']]}
# p15/p15165563/s57008959.txt {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 33, 'end_ix': 33, 'relations': [['located_at', '7'], ['suggestive_of', '12'], ['suggestive_of', '15']]}
# p15/p15165563/s57008959.txt {'tokens': 'findings', 'label': 'OBS-DP', 'start_ix': 55, 'end_ix': 55, 'relations': [['modify', '8']]}
# p15/p15078112/s56882127.txt {'tokens': 'tip', 'label': 'OBS-DP', 'start_ix': 65, 'end_ix': 65, 'relations': [['modify', '9'], ['located_at', '12']]}
# p18/p18026902/s55810062.txt {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 42, 'end_ix': 42, 'relations': [['located_at', '1'], ['located_at', '9']]}
# p18/p18022445/s51773947.txt {'tokens': 'opacification', 'label': 'OBS-DP', 'start_ix': 104, 'end_ix': 104, 'relations': [['suggestive_of', '24'], ['suggestive_of', '27']]}
# p18/p18010079/s52730761.txt {'tokens': 'obliquity of the patient', 'label': 'OBS-DP', 'start_ix': 66, 'end_ix': 69, 'relations': [['suggestive_of', '16']]}
# p18/p18002106/s50559874.txt {'tokens': 'diameter', 'label': 'OBS-DP', 'start_ix': 53, 'end_ix': 53, 'relations': [['modify', '4']]}
# p18/p18002106/s50559874.txt {'tokens': 'tension', 'label': 'OBS-DA', 'start_ix': 63, 'end_ix': 63, 'relations': [['modify', '4']]}
# p15/p15002678/s50618143.txt {'tokens': 'opacity', 'label': 'OBS-DP', 'start_ix': 42, 'end_ix': 42, 'relations': [['located_at', '4'], ['suggestive_of', '9'], ['suggestive_of', '11']]}
# p15/p15002678/s50618143.txt {'tokens': 'opacity', 'label': 'OBS-DP', 'start_ix': 42, 'end_ix': 42, 'relations': [['located_at', '4'], ['suggestive_of', '9'], ['suggestive_of', '11']]}
# p15/p15002678/s50618143.txt {'tokens': 'consolidation', 'label': 'OBS-U', 'start_ix': 58, 'end_ix': 58, 'relations': [['located_at', '4']]}
# p15/p15002678/s50618143.txt {'tokens': 'scarring', 'label': 'OBS-U', 'start_ix': 65, 'end_ix': 65, 'relations': [['located_at', '4']]}
# p15/p15002678/s50618143.txt {'tokens': 'opacity', 'label': 'OBS-DP', 'start_ix': 125, 'end_ix': 125, 'relations': [['located_at', '41'], ['suggestive_of', '44'], ['suggestive_of', '45']]}
# p15/p15002678/s50618143.txt {'tokens': 'opacity', 'label': 'OBS-DP', 'start_ix': 125, 'end_ix': 125, 'relations': [['located_at', '41'], ['suggestive_of', '44'], ['suggestive_of', '45']]}
# p18/p18028999/s57987829.txt {'tokens': 'pulled back about 5 cm', 'label': 'OBS-DP', 'start_ix': 141, 'end_ix': 145, 'relations': [['located_at', '20'], ['modify', '24']]}
# p18/p18020943/s53949676.txt {'tokens': 'consolidation', 'label': 'OBS-DP', 'start_ix': 106, 'end_ix': 106, 'relations': [['located_at', '6'], ['suggestive_of', '9']]}
# p18/p18020943/s53949676.txt {'tokens': 'lucency', 'label': 'OBS-DP', 'start_ix': 141, 'end_ix': 141, 'relations': [['modify', '13'], ['suggestive_of', '20'], ['suggestive_of', '21']]}
# p18/p18000745/s53121171.txt {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 45, 'end_ix': 45, 'relations': [['located_at', '3'], ['located_at', '7'], ['suggestive_of', '13'], ['suggestive_of', '14'], ['suggestive_of', '16']]}
# p18/p18000745/s53121171.txt {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 45, 'end_ix': 45, 'relations': [['located_at', '3'], ['located_at', '7'], ['suggestive_of', '13'], ['suggestive_of', '14'], ['suggestive_of', '16']]}
# p18/p18000745/s53121171.txt {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 45, 'end_ix': 45, 'relations': [['located_at', '3'], ['located_at', '7'], ['suggestive_of', '13'], ['suggestive_of', '14'], ['suggestive_of', '16']]}
# p18/p18000745/s59984925.txt {'tokens': 'Findings', 'label': 'OBS-DP', 'start_ix': 82, 'end_ix': 82, 'relations': [['modify', '4'], ['suggestive_of', '13'], ['suggestive_of', '14']]}
# p18/p18000745/s51763935.txt {'tokens': 'This', 'label': 'OBS-DP', 'start_ix': 62, 'end_ix': 62, 'relations': [['modify', '4'], ['suggestive_of', '11'], ['suggestive_of', '13']]}
# p15/p15009504/s59050955.txt {'tokens': 'This', 'label': 'OBS-DP', 'start_ix': 76, 'end_ix': 76, 'relations': [['modify', '6'], ['suggestive_of', '20'], ['suggestive_of', '21']]}
# p10/p10004235/s52962553.txt {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 100, 'end_ix': 100, 'relations': [['located_at', '23'], ['suggestive_of', '29']]}
# p10/p10004235/s58604118.txt {'tokens': 'tip', 'label': 'OBS-DP', 'start_ix': 57, 'end_ix': 57, 'relations': [['modify', '3'], ['located_at', '7']]}
# p18/p18015004/s57985812.txt {'tokens': 'tip', 'label': 'OBS-DP', 'start_ix': 168, 'end_ix': 168, 'relations': [['modify', '31'], ['located_at', '35']]}
# p18/p18015004/s56533254.txt {'tokens': 'consolidation', 'label': 'OBS-DP', 'start_ix': 69, 'end_ix': 69, 'relations': [['located_at', '12'], ['suggestive_of', '14'], ['suggestive_of', '15'], ['suggestive_of', '17']]}
# p18/p18015004/s56533254.txt {'tokens': 'consolidation', 'label': 'OBS-DP', 'start_ix': 69, 'end_ix': 69, 'relations': [['located_at', '12'], ['suggestive_of', '14'], ['suggestive_of', '15'], ['suggestive_of', '17']]}
# p18/p18015004/s56533254.txt {'tokens': 'consolidation', 'label': 'OBS-DP', 'start_ix': 69, 'end_ix': 69, 'relations': [['located_at', '12'], ['suggestive_of', '14'], ['suggestive_of', '15'], ['suggestive_of', '17']]}
# p18/p18015004/s54721527.txt {'tokens': 'Its', 'label': 'OBS-DP', 'start_ix': 96, 'end_ix': 96, 'relations': [['modify', '17'], ['located_at', '24']]}
# p10/p10003019/s58365492.txt {'tokens': 'suture', 'label': 'OBS-DP', 'start_ix': 50, 'end_ix': 50, 'relations': [['located_at', '4']]}
# p10/p10003019/s58505074.txt {'tokens': 'opacity', 'label': 'OBS-DP', 'start_ix': 72, 'end_ix': 72, 'relations': [['located_at', '25'], ['suggestive_of', '38']]}
# p10/p10003019/s58505074.txt {'tokens': 'opacity', 'label': 'OBS-DP', 'start_ix': 96, 'end_ix': 96, 'relations': [['suggestive_of', '32'], ['suggestive_of', '33']]}
# p10/p10003019/s58505074.txt {'tokens': 'opacity', 'label': 'OBS-DP', 'start_ix': 96, 'end_ix': 96, 'relations': [['suggestive_of', '32'], ['suggestive_of', '33']]}
# p10/p10003019/s58505074.txt {'tokens': 'it', 'label': 'OBS-DP', 'start_ix': 116, 'end_ix': 116, 'relations': [['modify', '21']]}
# p15/p15009233/s59402206.txt {'tokens': 'This', 'label': 'OBS-DP', 'start_ix': 135, 'end_ix': 135, 'relations': [['modify', '26'], ['suggestive_of', '29']]}
# p15/p15009233/s59402206.txt {'tokens': 'it', 'label': 'OBS-DP', 'start_ix': 149, 'end_ix': 149, 'relations': [['modify', '26']]}
# p10/p10002428/s57887188.txt {'tokens': 'opacification', 'label': 'OBS-DP', 'start_ix': 74, 'end_ix': 74, 'relations': [['located_at', '21'], ['suggestive_of', '23'], ['suggestive_of', '25']]}
# p10/p10002428/s54020701.txt {'tokens': 'advanced', 'label': 'OBS-DP', 'start_ix': 50, 'end_ix': 50, 'relations': [['modify', '4'], ['modify', '8']]}
# p18/p18006842/s56350245.txt {'tokens': 'enlargement', 'label': 'OBS-DP', 'start_ix': 142, 'end_ix': 142, 'relations': [['located_at', '39'], ['suggestive_of', '43'], ['suggestive_of', '45']]}
# p18/p18006842/s56350245.txt {'tokens': 'enlargement', 'label': 'OBS-DP', 'start_ix': 142, 'end_ix': 142, 'relations': [['located_at', '39'], ['suggestive_of', '43'], ['suggestive_of', '45']]}
# p15/p15002496/s54796318.txt {'tokens': 'opacity', 'label': 'OBS-DP', 'start_ix': 61, 'end_ix': 61, 'relations': [['located_at', '14'], ['suggestive_of', '18'], ['suggestive_of', '19']]}
# p15/p15002496/s54796318.txt {'tokens': 'opacity', 'label': 'OBS-DP', 'start_ix': 61, 'end_ix': 61, 'relations': [['located_at', '14'], ['suggestive_of', '18'], ['suggestive_of', '19']]}
# p15/p15007710/s57675460.txt {'tokens': 'It', 'label': 'OBS-DP', 'start_ix': 73, 'end_ix': 73, 'relations': [['modify', '9']]}
# p18/p18011616/s50686187.txt {'tokens': 'abnormality', 'label': 'OBS-DP', 'start_ix': 104, 'end_ix': 104, 'relations': [['located_at', '29'], ['suggestive_of', '34'], ['suggestive_of', '36']]}
# p18/p18011616/s50686187.txt {'tokens': 'abnormality', 'label': 'OBS-DP', 'start_ix': 104, 'end_ix': 104, 'relations': [['located_at', '29'], ['suggestive_of', '34'], ['suggestive_of', '36']]}
# p10/p10005024/s59581256.txt {'tokens': 'locations', 'label': 'ANAT-DP', 'start_ix': 126, 'end_ix': 126, 'relations': [['modify', '19']]}
# p18/p18028180/s57826518.txt {'tokens': 'low', 'label': 'OBS-DP', 'start_ix': 123, 'end_ix': 123, 'relations': [['located_at', '23'], ['suggestive_of', '29']]}
# p18/p18028180/s57826518.txt {'tokens': 'flattened', 'label': 'OBS-DP', 'start_ix': 129, 'end_ix': 129, 'relations': [['located_at', '23'], ['suggestive_of', '29']]}
# p18/p18028180/s57826518.txt {'tokens': 'hypertranslucent', 'label': 'OBS-DP', 'start_ix': 134, 'end_ix': 134, 'relations': [['located_at', '28'], ['suggestive_of', '29']]}
# p18/p18028180/s55973443.txt {'tokens': 'density', 'label': 'OBS-DP', 'start_ix': 126, 'end_ix': 126, 'relations': [['suggestive_of', '35'], ['suggestive_of', '36']]}
# p18/p18028180/s55973443.txt {'tokens': 'density', 'label': 'OBS-DP', 'start_ix': 126, 'end_ix': 126, 'relations': [['suggestive_of', '35'], ['suggestive_of', '36']]}
# p18/p18013971/s52981585.txt {'tokens': 'opacity', 'label': 'OBS-DP', 'start_ix': 27, 'end_ix': 27, 'relations': [['located_at', '5'], ['suggestive_of', '9'], ['suggestive_of', '10']]}
# p18/p18013971/s52981585.txt {'tokens': 'Aspiration', 'label': 'OBS-U', 'start_ix': 48, 'end_ix': 48, 'relations': [['located_at', '8']]}
# p18/p18012429/s57597557.txt {'tokens': 'consolidative', 'label': 'OBS-DP', 'start_ix': 43, 'end_ix': 43, 'relations': [['located_at', '6'], ['suggestive_of', '11'], ['suggestive_of', '18']]}
# p18/p18012429/s57597557.txt {'tokens': 'consolidative', 'label': 'OBS-DP', 'start_ix': 43, 'end_ix': 43, 'relations': [['located_at', '6'], ['suggestive_of', '11'], ['suggestive_of', '18']]}
# p18/p18012429/s54385664.txt {'tokens': 'infiltrate', 'label': 'OBS-DP', 'start_ix': 165, 'end_ix': 165, 'relations': [['located_at', '32'], ['suggestive_of', '37'], ['suggestive_of', '38']]}
# p18/p18012429/s54385664.txt {'tokens': 'infiltrate', 'label': 'OBS-DP', 'start_ix': 165, 'end_ix': 165, 'relations': [['located_at', '32'], ['suggestive_of', '37'], ['suggestive_of', '38']]}
# p18/p18012429/s50784640.txt {'tokens': 'increased', 'label': 'OBS-DP', 'start_ix': 87, 'end_ix': 87, 'relations': [['modify', '14'], ['suggestive_of', '18'], ['suggestive_of', '23']]}
# p18/p18012429/s50784640.txt {'tokens': 'Increased', 'label': 'OBS-DP', 'start_ix': 134, 'end_ix': 134, 'relations': [['modify', '28'], ['suggestive_of', '32'], ['suggestive_of', '37']]}
# p18/p18012429/s56346117.txt {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 68, 'end_ix': 68, 'relations': [['located_at', '16'], ['located_at', '19'], ['suggestive_of', '23'], ['suggestive_of', '25']]}
# p18/p18012429/s56346117.txt {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 68, 'end_ix': 68, 'relations': [['located_at', '16'], ['located_at', '19'], ['suggestive_of', '23'], ['suggestive_of', '25']]}
# p15/p15005501/s57651699.txt {'tokens': 'congestion', 'label': 'OBS-DA', 'start_ix': 69, 'end_ix': 69, 'relations': [['located_at', '9']]}
# p15/p15005501/s57651699.txt {'tokens': 'edema', 'label': 'OBS-DA', 'start_ix': 71, 'end_ix': 71, 'relations': [['located_at', '9']]}
# p10/p10002013/s52163036.txt {'tokens': 'pneumothorax', 'label': 'OBS-DP', 'start_ix': 88, 'end_ix': 88, 'relations': [['located_at', '35']]}
# p10/p10002013/s52163036.txt {'tokens': 'effusion', 'label': 'OBS-DP', 'start_ix': 91, 'end_ix': 91, 'relations': [['located_at', '35']]}
# p10/p10002430/s56345275.txt {'tokens': 'right', 'label': 'ANAT-DP', 'start_ix': 120, 'end_ix': 120, 'relations': [['modify', '22']]}
# p10/p10002430/s56345275.txt {'tokens': 'superimposed', 'label': 'OBS-DP', 'start_ix': 124, 'end_ix': 124, 'relations': [['modify', '20'], ['modify', '30']]}
# p10/p10001884/s59305618.txt {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 78, 'end_ix': 78, 'relations': [['located_at', '18'], ['suggestive_of', '20'], ['suggestive_of', '23']]}
# p10/p10001884/s59305618.txt {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 78, 'end_ix': 78, 'relations': [['located_at', '18'], ['suggestive_of', '20'], ['suggestive_of', '23']]}
# 6 {'tokens': 'cardiomegaly', 'label': 'OBS-DP', 'start_ix': 56, 'end_ix': 56, 'relations': [['modify', '36']]}
# 6 {'tokens': 'pattern', 'label': 'OBS-DP', 'start_ix': 68, 'end_ix': 68, 'relations': [['located_at', '19'], ['modify', '36']]}
# 6 {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 84, 'end_ix': 84, 'relations': [['located_at', '27'], ['modify', '36']]}
# 6 {'tokens': 'effusions', 'label': 'OBS-DP', 'start_ix': 93, 'end_ix': 93, 'relations': [['located_at', '34'], ['modify', '36']]}
# 48 {'tokens': 'scarring', 'label': 'OBS-DP', 'start_ix': 81, 'end_ix': 81, 'relations': [['located_at', '6'], ['located_at', '7'], ['suggestive_of', '15']]}
# 48 {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 115, 'end_ix': 115, 'relations': [['located_at', '23'], ['suggestive_of', '25'], ['suggestive_of', '26']]}
# 48 {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 115, 'end_ix': 115, 'relations': [['located_at', '23'], ['suggestive_of', '25'], ['suggestive_of', '26']]}
# 7 {'tokens': 'consolidation', 'label': 'OBS-DP', 'start_ix': 51, 'end_ix': 51, 'relations': [['located_at', '8'], ['suggestive_of', '12'], ['suggestive_of', '15']]}
# 7 {'tokens': 'consolidation', 'label': 'OBS-DP', 'start_ix': 51, 'end_ix': 51, 'relations': [['located_at', '8'], ['suggestive_of', '12'], ['suggestive_of', '15']]}
# 28 {'tokens': 'calcifications', 'label': 'OBS-DP', 'start_ix': 221, 'end_ix': 221, 'relations': [['located_at', '65'], ['suggestive_of', '70'], ['suggestive_of', '71']]}
# 28 {'tokens': 'calcifications', 'label': 'OBS-DP', 'start_ix': 221, 'end_ix': 221, 'relations': [['located_at', '65'], ['suggestive_of', '70'], ['suggestive_of', '71']]}
# 13 {'tokens': 'curvature', 'label': 'OBS-DP', 'start_ix': 123, 'end_ix': 123, 'relations': [['located_at', '40'], ['suggestive_of', '43'], ['suggestive_of', '44']]}
# 13 {'tokens': 'curvature', 'label': 'OBS-DP', 'start_ix': 123, 'end_ix': 123, 'relations': [['located_at', '40'], ['suggestive_of', '43'], ['suggestive_of', '44']]}
# 9 {'tokens': 'cephalization', 'label': 'OBS-DP', 'start_ix': 52, 'end_ix': 52, 'relations': [['suggestive_of', '24']]}
# 9 {'tokens': 'effusions', 'label': 'OBS-DP', 'start_ix': 56, 'end_ix': 56, 'relations': [['located_at', '18'], ['suggestive_of', '24']]}
# 36 {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 112, 'end_ix': 112, 'relations': [['located_at', '37'], ['suggestive_of', '39'], ['suggestive_of', '42']]}
# 36 {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 112, 'end_ix': 112, 'relations': [['located_at', '37'], ['suggestive_of', '39'], ['suggestive_of', '42']]}
# 36 {'tokens': 'nodular', 'label': 'OBS-DP', 'start_ix': 145, 'end_ix': 145, 'relations': [['located_at', '46'], ['suggestive_of', '47']]}
# p10/p10002013/s52163036.txt {'tokens': 'pneumothorax', 'label': 'OBS-DP', 'start_ix': 88, 'end_ix': 88, 'relations': [['located_at', '35']]}
# p10/p10002013/s52163036.txt {'tokens': 'effusion', 'label': 'OBS-DP', 'start_ix': 91, 'end_ix': 91, 'relations': [['located_at', '35']]}
# p10/p10002430/s56345275.txt {'tokens': 'right', 'label': 'ANAT-DP', 'start_ix': 120, 'end_ix': 120, 'relations': [['modify', '23']]}
# p10/p10002430/s56345275.txt {'tokens': 'superimposed', 'label': 'OBS-DP', 'start_ix': 124, 'end_ix': 124, 'relations': [['modify', '21'], ['modify', '32']]}
# 6 {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 84, 'end_ix': 84, 'relations': [['located_at', '27'], ['modify', '36']]}
# 6 {'tokens': 'effusions', 'label': 'OBS-DP', 'start_ix': 93, 'end_ix': 93, 'relations': [['located_at', '34'], ['modify', '36']]}
# 48 {'tokens': 'thickening', 'label': 'OBS-DP', 'start_ix': 41, 'end_ix': 41, 'relations': [['located_at', '3'], ['modify', '6'], ['suggestive_of', '7']]}
# 48 {'tokens': 'thickening', 'label': 'OBS-DP', 'start_ix': 41, 'end_ix': 41, 'relations': [['located_at', '3'], ['modify', '6'], ['suggestive_of', '7']]}
# 48 {'tokens': 'scarring', 'label': 'OBS-DP', 'start_ix': 81, 'end_ix': 81, 'relations': [['located_at', '10'], ['located_at', '11'], ['located_at', '15'], ['located_at', '18'], ['suggestive_of', '19']]}
# 48 {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 115, 'end_ix': 115, 'relations': [['located_at', '28'], ['suggestive_of', '30'], ['suggestive_of', '32']]}
# 48 {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 115, 'end_ix': 115, 'relations': [['located_at', '28'], ['suggestive_of', '30'], ['suggestive_of', '32']]}
# 7 {'tokens': 'consolidation', 'label': 'OBS-DP', 'start_ix': 51, 'end_ix': 51, 'relations': [['located_at', '8'], ['suggestive_of', '12'], ['suggestive_of', '14']]}
# 7 {'tokens': 'consolidation', 'label': 'OBS-DP', 'start_ix': 51, 'end_ix': 51, 'relations': [['located_at', '8'], ['suggestive_of', '12'], ['suggestive_of', '14']]}
# 28 {'tokens': 'calcifications', 'label': 'OBS-DP', 'start_ix': 221, 'end_ix': 221, 'relations': [['modify', '63'], ['suggestive_of', '68'], ['suggestive_of', '70']]}
# 28 {'tokens': 'calcifications', 'label': 'OBS-DP', 'start_ix': 221, 'end_ix': 221, 'relations': [['modify', '63'], ['suggestive_of', '68'], ['suggestive_of', '70']]}
# 13 {'tokens': 'curvature', 'label': 'OBS-DP', 'start_ix': 123, 'end_ix': 123, 'relations': [['located_at', '41'], ['suggestive_of', '44'], ['suggestive_of', '45']]}
# 13 {'tokens': 'curvature', 'label': 'OBS-DP', 'start_ix': 123, 'end_ix': 123, 'relations': [['located_at', '41'], ['suggestive_of', '44'], ['suggestive_of', '45']]}
# 9 {'tokens': 'cephalization', 'label': 'OBS-DP', 'start_ix': 52, 'end_ix': 52, 'relations': [['suggestive_of', '22']]}
# 9 {'tokens': 'effusions', 'label': 'OBS-DP', 'start_ix': 56, 'end_ix': 56, 'relations': [['located_at', '16'], ['suggestive_of', '22']]}
# 9 {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 59, 'end_ix': 59, 'relations': [['located_at', '18'], ['suggestive_of', '22']]}
# 36 {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 112, 'end_ix': 112, 'relations': [['located_at', '40'], ['suggestive_of', '42'], ['suggestive_of', '43']]}
# 36 {'tokens': 'opacities', 'label': 'OBS-DP', 'start_ix': 112, 'end_ix': 112, 'relations': [['located_at', '40'], ['suggestive_of', '42'], ['suggestive_of', '43']]}
# 36 {'tokens': 'component', 'label': 'OBS-DP', 'start_ix': 147, 'end_ix': 147, 'relations': [['located_at', '48'], ['suggestive_of', '49']]}
